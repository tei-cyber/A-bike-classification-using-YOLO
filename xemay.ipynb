# %%
# !pip install ultralytics

# %%
# !pip install roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 134.1 MB/s eta 0:00:0000:01

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bCy7psbAGMMLmbvemJpJ")
project = rf.workspace("xe-lgq2s").project("xe-may-qhsd0")
dataset = project.version(1).download("yolov26", location="/content/dataset")

# Then point training to:
data = "/content/dataset/data.yaml"

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo26m.pt")

results = model.train(
    data="data.yaml", 
    imgsz=640,
    epochs=500,
    patience=75,
    save=True,
    save_period=25,
    project="../runs/train",
    name="superbike_detector",
    exist_ok=True,
    batch=16,
    workers=8,
    cache="disk",
    amp=True,
    optimizer="AdamW",
    lr0=0.001,
    cos_lr=True,
    label_smoothing=0.1,
    dropout=0.1,

    # Roboflow already did it (3x)
    hsv_h=0.0,
    hsv_s=0.0,
    hsv_v=0.0,
    fliplr=0.0,
    flipud=0.0,
    degrees=0.0,
    shear=0.0,
    mosaic=0.0,
    mixup=0.0,
    translate=0.0,
)
# Out:
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.80  Python-3.11.14 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...
